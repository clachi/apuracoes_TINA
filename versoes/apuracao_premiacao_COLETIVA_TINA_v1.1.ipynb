# %%
import pandas as pd
import numpy as np

# %%
#sufixo="_ativos_mes_anterior"
sufixo=""

# %%
empresa='TELHANORTE'

# %%
# Dia da apuração
hoje = pd.to_datetime('today').date()
#hoje = pd.to_datetime('27/04/2022', format="%d/%m/%Y").date()
ANO=str(hoje.year)

# %%
# IDENTIFICAÇÃO SE TELHANORTE OU TUMELERO
ID_UNN=1 # 1=TELHANORTE    4=TUMELERO

# %%
# MÍNIMO NPS CONSIDERADO PARA ELEGIBILIDADE DA LOJA AO PRÊMIO COLETIVO TINA
NPS_ALVO=65

# %%
# Dias a serem considerados

MES_COMERCIAL=30 # MES COMERCIAL TEM 30 DIAS
MEIO_MES=int(MES_COMERCIAL/2.)

# %%
MESES= ['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
I_MESES= ['01','02','03','04','05','06','07','08','09','10','11','12']
MES=MESES[hoje.month-1]
I_MES=I_MESES[MESES.index(MES)]
I_MES_ANTERIOR=I_MESES[MESES.index(MES)-1]

# %%
I_MES
# Out:
# '05'

# %%
MES_ANTERIOR=MESES[MESES.index(MES)-1]
MES_ANTERIOR
# Out:
# 'abr'

# %%
print('Como a apuração está sendo feita em '+MES+', a apuração coletiva será correspondente ao do mês anterior '+MES_ANTERIOR)
# Out:
# Como a apuração está sendo feita em mai, a apuração coletiva será correspondente ao do mês anterior abr

# %%
I_DIAS=pd.to_datetime(ANO+'-'+I_MES_ANTERIOR).days_in_month

# %%
print(str(I_DIAS)+' dias em '+MES_ANTERIOR)
# Out:
# 30 dias em abr

# %%
# Período de Apuração   -   Faltas injustificadas no período
# Fevereiro de 2022
DATA_I = pd.to_datetime(ANO+'-'+I_MES_ANTERIOR+'-01', format='%Y/%m/%d')  # data inicial AAAA-MM-DD
DATA_F = pd.to_datetime(ANO+'-'+I_MES_ANTERIOR+'-'+str(I_DIAS), format='%Y/%m/%d')  # data final AAAA-MM-DD
print('Considerando ')
print('Data de início:')
print(DATA_I)
print('')
print('Data final:')
print(DATA_F)
# Out:
# Considerando
# Data de início:
# 2022-04-01 00:00:00
#
# Data final:
# 2022-04-30 00:00:00

# %%
# Diretório ou pasta base
DIRETORIO='C:/apuracao/'+empresa+'/'
print('Dentro da pasta '+DIRETORIO+' tem a pasta ano e mês? Se não crie como explicado a seguir.')
# Out:
# Dentro da pasta C:/apuracao/TELHANORTE/ tem a pasta ano e mês? Se não crie como explicado a seguir.

# %%
print('A apuração da premiação coletiva é correspondente ao mês anterior.')
print('Portanto, buscar arquivos do mês anterior na pasta:')
DIRETORIO_ANTERIOR=DIRETORIO+ANO+'/'+MES_ANTERIOR+'/'
print(DIRETORIO_ANTERIOR)
# Out:
# A apuração da premiação coletiva é correspondente ao mês anterior.
# Portanto, buscar arquivos do mês anterior na pasta:
# C:/apuracao/TELHANORTE/2022/abr/

# %%
DIRETORIO_INFO='C:/apuracao/info/'
print('Pasta com informações bases: '+DIRETORIO_INFO)
print('Aqui deve ter os arquivos com:')
# Out:
# Pasta com informações bases: C:/apuracao/info/
# Aqui deve ter os arquivos com:

# %%
# ARQUIVO DE ENTRADA: VALORES DE PREMIAÇÃO POR GRUPO DE CARGOS
F_PREMIO_CARGO=DIRETORIO_INFO+'premiacao_cargo_alvo.csv'
print(F_PREMIO_CARGO)
# Out:
# C:/apuracao/info/premiacao_cargo_alvo.csv

# %%
# ARQUIVO DE ENTRADA: CARGOS CONTEMPLADO PELA PREMIAÇÃO COLETIVA TINA
F_CARGOS=DIRETORIO_INFO+'cargos_contemplados_grupo.csv'
print(F_CARGOS)
# Out:
# C:/apuracao/info/cargos_contemplados_grupo.csv

# %%
# ARQUIVO DE ENTRADA: LOJAS TINA ROLL-OUT DE JANEIRO DE 2022 COM COD_LOJA, SIGLA E NOME
FILE_LOJAS_TINA=DIRETORIO_INFO+'lojas_pilotos_rollout.csv'
print(FILE_LOJAS_TINA)
# Out:
# C:/apuracao/info/lojas_pilotos_rollout.csv

# %%
# ARQUIVO DE ENTRADA: ALVOS COLETIVOS DAS LOJAS
F_ALVOS=DIRETORIO_INFO+'target_store.csv'
print('Arquivo de alvos coletivos')
print(F_ALVOS)
# Out:
# Arquivo de alvos coletivos
# C:/apuracao/info/target_store.csv

# %%
# PASTA COM ARQUIVOS BASES DO RH
DIRETORIO_ENTRA=DIRETORIO+ANO+'/'+MES+'/ORIGINAIS/'
print('Pasta:')
print(DIRETORIO_ENTRA)
print('Coloque nesta pasta os arquivos bases vindos do RH no mês da apuração:')
print('     base de ativos, ')
print('     base de falta injustificada; e')
print('     base de afastamentos.')
# Out:
# Pasta:
# C:/apuracao/TELHANORTE/2022/mai/ORIGINAIS/
# Coloque nesta pasta os arquivos bases vindos do RH no mês da apuração:
#      base de ativos,
#      base de falta injustificada; e
#      base de afastamentos.

# %%
# PASTA COM PLANILHA DE CHECAGEM PARA O ANALISTA DE NEGÓCIOS
DIRETORIO_CHECAGEM=DIRETORIO+ANO+'/'+MES+'/CHECAGEM/'
print('A planilha de checagem da apuração coletiva realizada em '+MES+' está aqui:')
print(DIRETORIO_CHECAGEM)
# Out:
# A planilha de checagem da apuração coletiva realizada em mai está aqui:
# C:/apuracao/TELHANORTE/2022/mai/CHECAGEM/

# %%
# PASTA COM BASES DE VENDAS PUXADAS DO MicroStrategy
DIRETORIO_VENDAS_NPS=DIRETORIO+ANO+'/'+MES_ANTERIOR+'/ORIGINAIS/' # pasta com vendas do MicroStrategy
print('Pasta:')
print(DIRETORIO_VENDAS_NPS)
print('Coloque nesta pasta a base de VENDAS de '+MES_ANTERIOR+' puxadas no MicroStrategy.')
# Out:
# Pasta:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/
# Coloque nesta pasta a base de VENDAS de abr puxadas no MicroStrategy.

# %%
# PASTA COM BASES DE NPS 
print('Pasta:')
print(DIRETORIO_VENDAS_NPS)
print('Coloque nesta pasta a base de NPS de '+MES_ANTERIOR+' baixada do SOLUX.')
# Out:
# Pasta:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/
# Coloque nesta pasta a base de NPS de abr baixada do SOLUX.

# %%
# PASTA DE SAÍDA DAS VERBAS DE PREMIAÇÕES TINA EM EXCEL A SEREM ENVIADOS AO RH
DIRETORIO_SAI=DIRETORIO+ANO+'/'+MES+'/para_RH/'

# %%
# ARQUIVO DE SAÍDA PARA O RH - EM EXCEL
FILE_SAI=DIRETORIO_SAI + "VERBA_4117_PREMIACAO_COLETIVA"+sufixo+".xlsx"
FILE_SAI_SEM=DIRETORIO_SAI + "VERBA_4117_PREMIACAO_COLETIVA_sem_considerar_falta_injustificada"+sufixo+".xlsx"
print('Arquivos de saída para RH')
print(FILE_SAI)
# Out:
# Arquivos de saída para RH
# C:/apuracao/TELHANORTE/2022/mai/para_RH/VERBA_4117_PREMIACAO_COLETIVA.xlsx

# %%
print('Arquivos de backup SEM CONSIDERAR FALTA INJUSTIFICADA')
print(FILE_SAI_SEM)
# Out:
# Arquivos de backup SEM CONSIDERAR FALTA INJUSTIFICADA
# C:/apuracao/TELHANORTE/2022/mai/para_RH/VERBA_4117_PREMIACAO_COLETIVA_sem_considerar_falta_injustificada.xlsx

# %%
# ARQUIO DE SAÍDA PARA CHECAGEM DO ANALISTA DE NEGÓCIOS - EM EXCEL
FILE_CHECAGEM=DIRETORIO_CHECAGEM + "CHECANDO_APURACAO_COLETIVA"+sufixo+".xlsx"
print('Planilha para checar a situação dos colaboradores em relação à Premiação Coletiva Tina')
print(FILE_CHECAGEM)
# Out:
# Planilha para checar a situação dos colaboradores em relação à Premiação Coletiva Tina
# C:/apuracao/TELHANORTE/2022/mai/CHECAGEM/CHECANDO_APURACAO_COLETIVA.xlsx

# %%
# ARQUIO DE SAÍDA PARA CHECAGEM DO ANALISTA DE NEGÓCIOS - EM EXCEL
FILE_CHECAGEM_LOJAS=DIRETORIO_CHECAGEM + "CHECANDO_LOJAS_APURACAO_COLETIVA"+sufixo+".xlsx"
print('Planilha para checar lojas elegíveis à Premiação Coletiva Tina')
print(FILE_CHECAGEM_LOJAS)
# Out:
# Planilha para checar lojas elegíveis à Premiação Coletiva Tina
# C:/apuracao/TELHANORTE/2022/mai/CHECAGEM/CHECANDO_LOJAS_APURACAO_COLETIVA.xlsx

# %%
# ARQUIVO DE ENTRADA: faltas injustificadas do mês e do mês anterior
F_FALTAS = DIRETORIO_ENTRA+"PREMIACOES TINA.xlsx"
F_FALTAS_MES_ANTERIOR=DIRETORIO_ANTERIOR+"ORIGINAIS/PREMIACOES TINA.xlsx"
print(F_FALTAS_MES_ANTERIOR)
print(F_FALTAS)
# Out:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/PREMIACOES TINA.xlsx
# C:/apuracao/TELHANORTE/2022/mai/ORIGINAIS/PREMIACOES TINA.xlsx

# %%
import os
# ARQUIVO DE ENTRADA: base de afastados do mês anterior
for file in os.listdir(DIRETORIO_ENTRA):
    if file.startswith('Empregados-Afastados-19000101-a-') & file.endswith('.xlsx'):
        F_AFASTADOS=os.path.join(DIRETORIO_ENTRA, file)
F_AFASTADOS # BASE DE AFASTAMENTOS DESDE O INÍCIO ATÉ O MÊS ANTERIOR
# Out:
# 'C:/apuracao/TELHANORTE/2022/mai/ORIGINAIS/Empregados-Afastados-19000101-a-20220430.xlsx'

# %%
# ARQUIVO DE ENTRADA: base de afastados do mês anterior
for arquivo in os.listdir(DIRETORIO_ENTRA):
    if arquivo.startswith('Empregados-Afastados-'+ANO+I_MES_ANTERIOR) & arquivo.endswith('.xlsx'):
        F_RETORNO=os.path.join(DIRETORIO_ENTRA, arquivo)
# ARQUIVO DE ENTRADA: base de afastados do mês anterior
F_RETORNO
# Out:
# 'C:/apuracao/TELHANORTE/2022/mai/ORIGINAIS/Empregados-Afastados-20220401-a-20220430.xlsx'

# %%
arquivo
# Out:
# 'wr2b-111909177.xlsx'

# %%
# ARQUIVO DE ENTRADA: NPS DAS LOJAS
FILE_NPS=DIRETORIO_VENDAS_NPS+'Ranking NPS.csv'
print(''+FILE_NPS)
# Out:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/Ranking NPS.csv

# %%
# ARQUIVO DE ENTRADA: VENDAS DO MÊS ANTERIOR 
FILE_VENDAS=DIRETORIO_VENDAS_NPS+'RECEITA_LOJA_MENSAL.xlsx'
print(FILE_VENDAS)
# Out:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/RECEITA_LOJA_MENSAL.xlsx

# %%
# ARQUIVO DE ENTRADA: base de ativos MAIS ATUALIZADO gerado pela ADP
nome_base='wr2b-111909177.xlsx'
#F_ATIVOS=DIRETORIO_ENTRA+nome_base
F_ATIVOS=DIRETORIO_ANTERIOR+'ORIGINAIS/'+nome_base
print(F_ATIVOS)
# Out:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/wr2b-111909177.xlsx

# %%
# CARREGANDO PRÊMIOS POR GRUPO DE CARGOS 
PREMIOS=pd.read_csv(F_PREMIO_CARGO, sep=';')

# %%
print(PREMIOS)
# Out:
#       Grupo  ALVO1  ALVO2
# 0        GG    800   1600
# 1         A    600   1200
# 2         B    400    800
# 3         C    200    400
# 4         D    100    200
# 5  NAO TINA      0      0

# %%
print(FILE_LOJAS_TINA)
# Out:
# C:/apuracao/info/lojas_pilotos_rollout.csv

# %%
# CARREGANDO TODAS AS LOJAS TINA DO ROLL-OUT DA TELHANORTE
lojas_tina=pd.read_csv(FILE_LOJAS_TINA,sep=';', encoding='latin1')

# %%
#TODO Se o mês for janeiro, pegar dezembro do ano anteriorf

# if MESES.index(MES) == 0:
#     MES_ANTERIOR=MES[11]
#     DIRETORIO_ANTERIOR=DIRETORIO+str(int(float(ANO))-1)+'/'+MES_ANTERIOR+'/originais/'
#     print(DIRETORIO_ANTERIOR)

# print(DIRETORIO_ANTERIOR)

# %%
# CARREGANDO ALVOS COLETIVOS DAS LOJAS
print('Carregando alvos coletivos do arquivo:')
print(F_ALVOS)
alvos=pd.read_csv(F_ALVOS, sep=';', encoding='latin1')
# Out:
# Carregando alvos coletivos do arquivo:
# C:/apuracao/info/target_store.csv

# %%
# FILTRANDO ALVOS DO MÊS ANTERIOR
alvos=alvos[(alvos['id_unn']==ID_UNN) & (alvos['id_mes']==int(float(ANO+I_MES_ANTERIOR)))].copy(deep=True)

# %%
alvos
# Out:
#      id_unn  id_fil  id_mes  target_sales_store_1  target_sales_store_2
# 117       1       1  202204               4222729               4417709
# 118       1      75  202204               1599580               1698420
# 119       1      24  202204               8462883               8794235
# 120       1      57  202204               2257801               2418465
# 121       1      31  202204               2513037               2695489
# 122       1      48  202204               1507592               1625143
# 123       1      52  202204               1702626               1820097
# 124       1      56  202204               3042992               3206973
# 125       1      36  202204               3011064               3203174
# 126       1      38  202204               2348111               2479512
# 127       1      32  202204               3290751               3501658
# 128       1      19  202204               8026309               8302751
# 129       1      12  202204               5201755               5417401
# 130       1      54  202204               2437710               2612566
# 131       1       3  202204              19556614              20365671
# 132       1      30  202204              10474420              10843131
# 133       1      27  202204               2024388               2169889
# 134       1      34  202204               2593292               2772994
# 135       1      29  202204               1768299               1951614
# 136       1       8  202204               3025118               3200657
# 137       1      37  202204               2538288               2689959
# 138       1      23  202204               2933834               3213696
# 139       1      55  202204               2927500               3139764
# 140       1      66  202204               2566428               2726896
# 141       1      71  202204               3627299               3868503
# 142       1      74  202204               2728981               2893058
# 143       1       9  202204               2982561               3141049
# 144       1      64  202204               5139625               5351774
# 145       1      72  202204               1753628               1873650
# 146       1      26  202204               5040452               5269598
# 147       1      28  202204               3843981               4039012
# 148       1      22  202204               2277617               2415186
# 149       1      40  202204               4403925               4614318
# 150       1      43  202204               3021009               3188370
# 151       1      73  202204               2126228               2274356
# 152       1      51  202204               3809933               3991701
# 153       1      39  202204               1892494               2039986
# 154       1      70  202204               1548968               1651055
# 155       1      25  202204               6496375               6800432

# %%
# # TROCANDO VÍRGULA POR PONTO PARA DECIMAIS
# # CONSIDERANDO SOMENTE COLUNA DOS ALVOS 1 E 2
# alvos['target_sales_store_1']=alvos['target_sales_store_1'].str.replace(",",".").astype(float)
# alvos['target_sales_store_2']=alvos['target_sales_store_2'].str.replace(",",".").astype(float)

# # CHECAGEM
# alvos

# %%
FILE_VENDAS
# Out:
# 'C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/RECEITA_LOJA_MENSAL.xlsx'

# %%
# CARREGANDO AS VENDAS DO MES ANTERIOR
print(FILE_VENDAS)
vendas=pd.read_excel(FILE_VENDAS) # 
if any(vendas['Loja']=="Total"): # Eliminando a linha com vendas totais
    vendas=vendas[vendas['Loja']!='Total']

# CHECAGEM
vendas
# Out:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/RECEITA_LOJA_MENSAL.xlsx
# c:\Users\C1075636\Miniconda3\envs\tina\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Loja                    Unnamed: 1 Unnamed: 2 Sigla  \
# 0     1                 TN-ANHANGUERA        ANH   ANH
# 1     3                   TN-MARGINAL        MGN   MGN
# 2     8               TN-PRAIA GRANDE        PGD   PGD
# 3     9              TN-SANTO ANDRÉ 1        SA1   SA1
# 4    12                    TN-JUNDIAÍ        JDI   JDI
# 5    19                 TN-IMIGRANTES        IMI   IMI
# 6    21                CANAL EMPRESAS        CEM   CEM
# 7    22                     TN-TABOÃO        TAB   TAB
# 8    23                  PRO-MARGINAL        PMG   PMG
# 9    24                 TN-ARICANDUVA        ARI   ARI
# 10   25                 TN-ZONA NORTE        ZNO   ZNO
# 11   26                   TN-SÃO JOSÉ        SJC   SJC
# 12   27                     TN-OSASCO        OSA   OSA
# 13   28                   TN-SOROCABA        SOR   SOR
# 14   29                PRO-ARICANDUVA        PAR   PAR
# 15   30                    TN-MORUMBI        MOR   MOR
# 16   31                  TN-BELVEDERE        BEL   BEL
# 17   32                  TN-GUARULHOS        GRU   GRU
# 18   34                   TN-PAMPULHA        PAM   PAM
# 19   36                   TN-CONTAGEM        CTG   CTG
# 20   37                 TN-PIRACICABA        PIR   PIR
# 21   38                    TN-D.PEDRO        DPE   DPE
# 22   39                 TN-UBERLÂNDIA        UBE   UBE
# 23   40                    TN-TAMBORÉ        TAM   TAM
# 24   43                    TN-TATUAPÉ        TAT   TAT
# 25   48          TN-BRAGANÇA PAULISTA        BRG   BRG
# 26   51                 TN-TIRADENTES        TIR   TIR
# 27   52                     TN-CATUAÍ        CAT   CAT
# 28   54                    TN-MARINGÁ        MGA   MGA
# 29   55        TN-PRESIDENTE PRUDENTE        PRU   PRU
# 30   56                TN-CAMPO LIMPO        CLI   CLI
# 31   57  TN-ARICANDUVA RIO DAS PEDRAS        ARP   ARP
# 32   58                  CD-GUARULHOS        CDG   CDG
# 33   60               CONCEITO BRASIL        CBR   CBR
# 34   62                    E-COMMERCE        ECO   ECO
# 35   64                     TN-SANTOS        SAN   SAN
# 36   66             TN-RAPOSO TAVARES        RAP   RAP
# 37   70            TN-WASHINGTON LUIS        WHL   WHL
# 38   71                 TN-RODA VIVA         RDV   RDV
# 39   72                 TN-SÃO CARLOS        SCA   SCA
# 40   73                    TN-TAUBATE        TBT   TBT
# 41   74           TN-RIBEIRAO PRETO 2        RPT   RPT
# 42   75                   TN_AMAZONAS        AMZ   AMZ
# 43   76                  OJ-AMOREIRAS        AMO   AMO
# 44   77                TN-SUMAREZINHO        SMZ   SMZ
# 45   78                      TN-MOEMA        MOE   MOE
# 46   81                  TN-ACLIMACAO        ACL   ACL
# 47   82                  TN-PINHEIROS        PIN   PIN
# 48   83                       TN-LAPA        LPA   LPA
# 49   84                     TN-TUIUTI        TUI   TUI
# 50   85                      TN-MOOCA        MOO   MOO
# 51   86                 TN-LEOPOLDINA        LEO   LEO
# 52   87             CENTRAL DE VENDAS        CDV   CDV
# 53   88                 TN-INDAIATUBA        IND   IND
#
#     Venda Bruta (Receita Caixa)
# 0                    3290470.81
# 1                   19755502.86
# 2                    2457010.48
# 3                    2883713.64
# 4                    5629601.58
# 5                    7651333.72
# 6                    2115511.47
# 7                    1935086.80
# 8                    2839836.89
# 9                    8077677.11
# 10                   6025262.19
# 11                   4647668.70
# 12                   1615072.13
# 13                   3281824.60
# 14                   1728748.41
# 15                  10236851.21
# 16                   1797914.63
# 17                   3067211.96
# 18                   2205361.70
# 19                   1830317.73
# 20                   2140641.81
# 21                   1804328.79
# 22                   1500313.55
# 23                   3889825.30
# 24                   3116576.28
# 25                   1595695.62
# 26                   2902479.81
# 27                   1338749.13
# 28                   1621650.37
# 29                   2152571.37
# 30                   2696604.22
# 31                   2089312.16
# 32                    251961.87
# 33                   1243127.82
# 34                   5876344.10
# 35                   3858814.93
# 36                   1949031.72
# 37                   1286499.53
# 38                   3447183.35
# 39                   1792661.11
# 40                   1792231.17
# 41                   1946969.77
# 42                   1070910.30
# 43                   2015594.72
# 44                    267080.07
# 45                    343989.02
# 46                    159095.28
# 47                    198216.78
# 48                    104914.31
# 49                    230155.91
# 50                     92334.05
# 51                    165912.77
# 52                    302555.75
# 53                    383089.44

# %%
# CARREGANDO NPS DAS LOJAS
print('Carregando NPS das lojas')
print(FILE_NPS)
nps_lojas=pd.read_csv(FILE_NPS,sep=';')
# Out:
# Carregando NPS das lojas
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/Ranking NPS.csv

# %%
# CHECAGEM
nps_lojas
# Out:
#        id  externalId   type                         title  group     nps  \
# 0   10135          85  store                      TN-MOOCA    NaN  100,0%
# 1   10134          84  store                     TN-TUIUTI    NaN  100,0%
# 2   10133          83  store                       TN-LAPA    NaN  100,0%
# 3   10070          82  store                  TN-PINHEIROS    NaN  100,0%
# 4   10009          21  store                CANAL EMPRESAS    NaN  100,0%
# 5   10008          60  store               CONCEITO BRASIL    NaN  100,0%
# 6   10071          78  store                      TN-MOEMA    NaN   95,0%
# 7   10040          39  store                 TN-UBERLÂNDIA    NaN   87,0%
# 8   10148          88  store                 TN-INDAIATUBA    NaN   86,7%
# 9   10069          81  store                  TN-ACLIMACAO    NaN   86,7%
# 10  10012          38  store                    TN-D.PEDRO    NaN   83,1%
# 11  10032          72  store                 TN-SÃO CARLOS    NaN   81,8%
# 12  10136          86  store                 TN-LEOPOLDINA    NaN   80,0%
# 13  10036          40  store                    TN-TAMBORÉ    NaN   80,0%
# 14  10026          55  store        TN-PRESIDENTE PRUDENTE    NaN   78,7%
# 15  10031          64  store                     TN-SANTOS    NaN   78,0%
# 16  10029          74  store           TN-RIBEIRAO PRETO 2    NaN   76,9%
# 17  10038          73  store                    TN-TAUBATE    NaN   74,5%
# 18  10005          31  store                  TN-BELVEDERE    NaN   72,5%
# 19  10018          54  store                    TN-MARINGÁ    NaN   72,2%
# 20  10011          36  store                   TN-CONTAGEM    NaN   72,1%
# 21  10027          66  store             TN-RAPOSO TAVARES    NaN   71,1%
# 22  10024          37  store                 TN-PIRACICABA    NaN   71,1%
# 23  10035          22  store                     TN-TABOÃO    NaN   70,6%
# 24  10020          27  store                     TN-OSASCO    NaN   70,6%
# 25  10039          51  store                 TN-TIRADENTES    NaN   69,8%
# 26  10002           1  store                 TN-ANHANGUERA    NaN   69,7%
# 27  10004          57  store  TN-ARICANDUVA RIO DAS PEDRAS    NaN   69,4%
# 28  10034          28  store                   TN-SOROCABA    NaN   69,2%
# 29  10017          12  store                    TN-JUNDIAÍ    NaN   68,6%
# 30  10046          26  store                   TN-SAO JOSE    NaN   67,7%
# 31  10028          71  store                  TN-RODA VIVA    NaN   67,6%
# 32  10006          48  store          TN-BRAGANÇA PAULISTA    NaN   67,4%
# 33  10037          43  store                    TN-TATUAPÉ    NaN   66,7%
# 34  10016          19  store                 TN-IMIGRANTES    NaN   64,6%
# 35  10007          52  store                     TN-CATUAÍ    NaN   63,6%
# 36  10042          25  store                 TN-ZONA NORTE    NaN   63,3%
# 37  10021          34  store                   TN-PAMPULHA    NaN   62,5%
# 38  10001          75  store                   TN_AMAZONAS    NaN   61,3%
# 39  10014          30  store                    TN-MORUMBI    NaN   61,0%
# 40  10030           9  store              TN-SANTO ANDRÉ 1    NaN   58,8%
# 41  10068          77  store                TN-SUMAREZINHO    NaN   58,6%
# 42  10022          29  store                PRO ARICANDUVA    NaN   58,5%
# 43  10015          32  store                  TN-GUARULHOS    NaN   57,9%
# 44  10010          56  store                TN-CAMPO LIMPO    NaN   57,4%
# 45  10013          62  store                    E-COMMERCE    NaN   57,0%
# 46  10023           8  store               TN-PRAIA GRANDE    NaN   56,9%
# 47  10003          24  store                 TN-ARICANDUVA    NaN   55,7%
# 48  10019           3  store                   TN-MARGINAL    NaN   55,4%
# 49  10025          23  store                  PRO MARGINAL    NaN   53,1%
# 50  10041          70  store            TN-WASHINGTON LUIS    NaN   48,9%
# 51  10147          87  store         CDV-CENTRAL DE VENDAS    NaN   40,0%
# 52  10061          58  store                  CD-GUARULHOS    NaN  -50,0%
#
#    samplingError  promoters  neutrals  detractors promoter % neutral %  \
# 0         100,0%          7         0           0     100,0%      0,0%
# 1         100,0%          8         0           0     100,0%      0,0%
# 2         100,0%          6         0           0     100,0%      0,0%
# 3         100,0%          5         0           0     100,0%      0,0%
# 4         100,0%          1         0           0     100,0%      0,0%
# 5         100,0%          9         0           0     100,0%      0,0%
# 6           9,7%         39         0           1      97,5%      0,0%
# 7         100,0%         20         3           0      87,0%     13,0%
# 8         100,0%         14         0           1      93,3%      0,0%
# 9         100,0%         14         0           1      93,3%      0,0%
# 10         12,6%         52         4           3      88,1%      6,8%
# 11         17,7%         29         2           2      87,9%      6,1%
# 12        100,0%         12         3           0      80,0%     20,0%
# 13         11,2%         68         8           4      85,0%     10,0%
# 14         12,9%         51         7           3      83,6%     11,5%
# 15         10,0%         91        12           6      83,5%     11,0%
# 16         16,6%         32         5           2      82,1%     12,8%
# 17         16,1%         38         6           3      80,9%     12,8%
# 18         19,6%         33         3           4      82,5%      7,5%
# 19         19,8%         29         4           3      80,6%     11,1%
# 20         19,7%         36         2           5      83,7%      4,7%
# 21         20,5%         31         3           4      81,6%      7,9%
# 22         18,1%         36         5           4      80,0%     11,1%
# 23         18,3%         42         3           6      82,4%      5,9%
# 24         20,8%         27         4           3      79,4%     11,8%
# 25         17,8%         43         4           6      81,1%      7,6%
# 26         13,9%         50        12           4      75,8%     18,2%
# 27         18,9%         40         3           6      81,6%      6,1%
# 28         19,0%         30         6           3      76,9%     15,4%
# 29         11,9%         81        15           9      77,1%     14,3%
# 30         16,0%         51         7           7      78,5%     10,8%
# 31         14,9%         52        10           6      76,5%     14,7%
# 32         19,0%         33         6           4      76,7%     14,0%
# 33         15,9%         54         7           8      78,3%     10,1%
# 34          8,9%        159        31          22      75,0%     14,6%
# 35         20,0%         33         6           5      75,0%     13,6%
# 36         11,7%        106        15          18      76,3%     10,8%
# 37         20,5%         37         4           7      77,1%      8,3%
# 38         24,8%         23         4           4      74,2%     12,9%
# 39         11,0%        118        20          21      74,2%     12,6%
# 40         16,1%         59         9          12      73,8%     11,3%
# 41         24,4%         20         6           3      69,0%     20,7%
# 42         22,4%         30         5           6      73,2%     12,2%
# 43         23,8%         28         4           6      73,7%     10,5%
# 44         18,9%         38         9           7      70,4%     16,7%
# 45          7,5%        285        39          64      73,5%     10,1%
# 46         17,6%         46        10           9      70,8%     15,4%
# 47         12,7%         84        22          16      68,9%     18,0%
# 48          7,7%        231        60          45      68,8%     17,9%
# 49         21,2%         34         7           8      69,4%     14,3%
# 50         21,2%         30        10           7      63,8%     21,3%
# 51        100,0%         10         1           4      66,7%      6,7%
# 52        100,0%          1         0           3      25,0%      0,0%
#
#    detractor %  transactions  surveys  ratings responseRate
# 0         0,0%       143.000   86.000        7         8,1%
# 1         0,0%       199.000  125.000        8         6,4%
# 2         0,0%       119.000   84.000        6         7,1%
# 3         0,0%       229.000  148.000        5         3,4%
# 4         0,0%         8.000    7.000        1        14,3%
# 5         0,0%       260.000  123.000        9         7,3%
# 6         2,5%       415.000  240.000       40        16,7%
# 7         0,0%         1.112  461.000       23         5,0%
# 8         6,7%       310.000  169.000       15         8,9%
# 9         6,7%       249.000  157.000       15         9,6%
# 10        5,1%         1.579  730.000       59         8,1%
# 11        6,1%         1.670  839.000       33         3,9%
# 12        0,0%       161.000  110.000       15        13,6%
# 13        5,0%         2.257    1.058       80         7,6%
# 14        4,9%         1.782  833.000       61         7,3%
# 15        5,5%         3.389    1.261      109         8,6%
# 16        5,1%         1.369  613.000       39         6,4%
# 17        6,4%         1.520  687.000       47         6,8%
# 18       10,0%         1.075  420.000       40         9,5%
# 19        8,3%         1.914  791.000       36         4,6%
# 20       11,6%         1.162  518.000       43         8,3%
# 21       10,5%         1.916  850.000       38         4,5%
# 22        8,9%         2.203  787.000       45         5,7%
# 23       11,8%         2.002  873.000       51         5,8%
# 24        8,8%         1.641  646.000       34         5,3%
# 25       11,3%         1.835  854.000       53         6,2%
# 26        6,1%         3.103    1.344       66         4,9%
# 27       12,2%         2.505  835.000       49         5,9%
# 28        7,7%         2.853  955.000       39         4,1%
# 29        8,6%         4.555    1.546      105         6,8%
# 30       10,8%         3.747    1.291       65         5,0%
# 31        8,8%         2.856    1.276       68         5,3%
# 32        9,3%         1.359  644.000       43         6,7%
# 33       11,6%         2.712    1.049       69         6,6%
# 34       10,4%         6.932    2.486      212         8,5%
# 35       11,4%         1.455  648.000       44         6,8%
# 36       13,0%         4.407    1.864      139         7,5%
# 37       14,6%         1.880  673.000       48         7,1%
# 38       12,9%         1.296  514.000       31         6,0%
# 39       13,2%         5.930    2.351      159         6,8%
# 40       15,0%         3.203    1.199       80         6,7%
# 41       10,3%       396.000  272.000       29        10,7%
# 42       14,6%         2.127  650.000       41         6,3%
# 43       15,8%         2.827  961.000       38         4,0%
# 44       13,0%         4.074    1.289       54         4,2%
# 45       16,5%        11.682    8.023      388         4,8%
# 46       13,8%         2.169  903.000       65         7,2%
# 47       13,1%         6.614    2.484      122         4,9%
# 48       13,4%        13.309    5.476      336         6,1%
# 49       16,3%         3.200  994.000       49         4,9%
# 50       14,9%         1.623  700.000       47         6,7%
# 51       26,7%       311.000  187.000       15         8,0%
# 52       75,0%       302.000  105.000        4         3,8%

# %%
# transformando vendas de caracteres para número
vendas = vendas[['Loja', 'Venda Bruta (Receita Caixa)']].rename(
        columns={'Loja':'cod_loja','Venda Bruta (Receita Caixa)':'Venda_Total'})

# %%
vendas['cod_loja']=vendas['cod_loja'].astype(float).astype(int)

# %%
# ORGANIZANDO VENDAS POR LOJA
loja_nps_venda_alvo=pd.merge(
    lojas_tina[['cod_loja', 'sigla_loja']],
    vendas, 
    how='left',on='cod_loja'
    )

# %%
# JUNTANDO NPS ÀS VENDAS
loja_nps_venda_alvo=pd.merge(
    loja_nps_venda_alvo,
    nps_lojas[['externalId','nps']].rename(
        columns={'externalId':'cod_loja'}
        ),how='left',on='cod_loja'
    )

# %%
# JUNTANDO OS ALVOS COLETIVOS ÀS VENDAS E NPS
loja_nps_venda_alvo=pd.merge(
    loja_nps_venda_alvo,
    alvos[['id_fil', 'id_mes', 'target_sales_store_1',
       'target_sales_store_2']].rename(
        columns={'id_fil':'cod_loja'}
        ),how='left',on='cod_loja'
    )

# %%
# FUNÇÃO PARA VERIFICAR SE ATINTIU ALVO1 OU ALVO2 OU NENHUM
def alvo_alcancado(venda, alvo1, alvo2):
    if venda >= alvo2:
        alvo='ALVO2'
    elif venda >= alvo1:
        alvo='ALVO1'
    else: alvo = 'NAO'
    return alvo

# %%
# VERIFICANDO SE A LOJA BATEU ALVO1, ALVO2 OU NÃO BATEU O ALVO
loja_nps_venda_alvo['alvo']=loja_nps_venda_alvo.apply(
    lambda x: alvo_alcancado(
        x['Venda_Total'], x['target_sales_store_1'], x['target_sales_store_2']
        ), axis=1).copy()

# %%
# TRANSFORMANDO OS CARACTERES CARACTERES DA NPS EM NÚMEROS 
# REMOVENDO % DE nps e trocando a vírgula por ponto e obter número com decimal
loja_nps_venda_alvo['nps']=loja_nps_venda_alvo['nps'].str.replace("%","")
loja_nps_venda_alvo['nps']=loja_nps_venda_alvo['nps'].str.replace(",",".").astype(float)

# %%
# FUNÇÃO PARA VERFICAR SE A LOJA BATEU A META DE NPS
def nps_alcancado(nps):
    global NPS_ALVO
    if nps >=NPS_ALVO:
        nps_loja='SIM'
    else: nps_loja = 'NAO'
    return nps_loja

# %%
# Verificando se a loja alcançou a NPS estabelecida
loja_nps_venda_alvo['NPS_alcancado']=loja_nps_venda_alvo['nps'].apply(
    lambda x: nps_alcancado(x)).copy()

# %%
# CHECAGEM
loja_nps_venda_alvo.to_excel(FILE_CHECAGEM_LOJAS, index=False)

# %%
loja_nps_venda_alvo[
    (loja_nps_venda_alvo['alvo'] != 'NAO')
]
# Out:
#     cod_loja sigla_loja  Venda_Total   nps    id_mes  target_sales_store_1  \
# 3         43        TAT   3116576.28  66.7  202204.0             3021009.0
# 5         12        JDI   5629601.58  68.6  202204.0             5201755.0
# 18         3        MGN  19755502.86  55.4  202204.0            19556614.0
# 31        48        BRG   1595695.62  67.4  202204.0             1507592.0
# 38        72        SCA   1792661.11  81.8  202204.0             1753628.0
#
#     target_sales_store_2   alvo NPS_alcancado
# 3              3188370.0  ALVO1           SIM
# 5              5417401.0  ALVO2           SIM
# 18            20365671.0  ALVO1           NAO
# 31             1625143.0  ALVO1           SIM
# 38             1873650.0  ALVO1           SIM

# %%
# Obtendo somente as lojas elegíveis à premiação coletiva da Tina 
print('LOJAS ELEGÍVEIS À PREMIAÇÃO COLETIVA:')
lojas_elegiveis = loja_nps_venda_alvo[
    (loja_nps_venda_alvo['alvo'] != 'NAO') & 
    (loja_nps_venda_alvo['NPS_alcancado'] == 'SIM')
    ].copy(deep=True)
lojas_elegiveis
# Out:
# LOJAS ELEGÍVEIS À PREMIAÇÃO COLETIVA:
#     cod_loja sigla_loja  Venda_Total   nps    id_mes  target_sales_store_1  \
# 3         43        TAT   3116576.28  66.7  202204.0             3021009.0
# 5         12        JDI   5629601.58  68.6  202204.0             5201755.0
# 31        48        BRG   1595695.62  67.4  202204.0             1507592.0
# 38        72        SCA   1792661.11  81.8  202204.0             1753628.0
#
#     target_sales_store_2   alvo NPS_alcancado
# 3              3188370.0  ALVO1           SIM
# 5              5417401.0  ALVO2           SIM
# 31             1625143.0  ALVO1           SIM
# 38             1873650.0  ALVO1           SIM

# %%
# Lendo faltas injustificadas dos colaboradores
print("Lendo faltas injustificadas do arquivo:")
print(F_FALTAS_MES_ANTERIOR+' tem ocorrências do dia 01 até 15 do mês anterior.')
print(F_FALTAS+' tem ocorrências do dia 16 do mês anterior até 15 do mês atual.')
faltas_inj = pd.read_excel(F_FALTAS, header=0) # Tem ocorrências do dia 16 do mes anterior até 15 do mes atual. Vou pegar somente do 16 ao final do mês anterior.
faltas_mes_anterior=pd.read_excel(F_FALTAS_MES_ANTERIOR, header=0) # para pegar as ocorrências do dia 01 até o dia 15 do mês anterior
# Out:
# Lendo faltas injustificadas do arquivo:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/PREMIACOES TINA.xlsx tem ocorrências do dia 01 até 15 do mês anterior.
# C:/apuracao/TELHANORTE/2022/mai/ORIGINAIS/PREMIACOES TINA.xlsx tem ocorrências do dia 16 do mês anterior até 15 do mês atual.

# %%
# Juntando as bases do mês passado e delimitando para o período de apuração
todas_faltas=pd.concat([faltas_mes_anterior, faltas_inj], axis=0)
faltas = todas_faltas[(todas_faltas['DATA DA OCORRÊNCIA'] >= DATA_I) &
           (todas_faltas['DATA DA OCORRÊNCIA'] <= DATA_F)].copy()
faltas['DATA DA OCORRÊNCIA'].sort_values()
# Out:
# 237   2022-04-01
# 77    2022-04-01
# 93    2022-04-01
# 184   2022-04-01
# 153   2022-04-01
#          ...
# 198   2022-04-14
# 288   2022-04-14
# 288   2022-04-14
# 49    2022-04-14
# 118   2022-04-14
# Name: DATA DA OCORRÊNCIA, Length: 310, dtype: datetime64[ns]

# %%
# Renomeando a coluna da MATRICULA nas faltas 
faltas.rename(columns={'MATR EMPR':'MATRICULA'}, inplace=True)

# %%
# CHECAGEM
# Somente para verificar se o colaborador teve falta na período
faltas[faltas['MATRICULA']==28017]
# Out:
# Empty DataFrame
# Columns: [PERIODO - DTINI, PERIODO - DTFIM, EMPRESA, DATA DA OCORRÊNCIA, COD ESTAB, NOME ESTAB, COD CR, NOME CR, CÓDIGO DO CENTRO CUSTO CONTABILIDADE, MATR CHEFIA, NOME CHEFIA, MATRICULA, NOME EMPPR, FUNCAO-DENOMINACAO, COD VERBA, DESCRICAO VERBA, VALOR]
# Index: []

# %%
# Lendo base de ativos
print("Lendo base de ativos no arquivo:")
print(F_ATIVOS)
#base_ativos = pd.read_excel(F_ATIVOS, header=0) # 
base_ativos = pd.read_excel(F_ATIVOS) #
# Out:
# Lendo base de ativos no arquivo:
# C:/apuracao/TELHANORTE/2022/abr/ORIGINAIS/wr2b-111909177.xlsx

# %%
# Removendo espaços em branco do nome da coluna 
base_ativos.columns = base_ativos.columns.str.strip()
print(base_ativos.columns)
# Out:
# Index(['Estabelecimento - Código', 'Matrícula', 'Nome - Primeiro Nome',
#        'Nome - Sobrenome', 'Cargo - Código', 'Cargo - Nome',
#        'Data de Nascimento', 'Data da Admissão',
#        'Situação do Empregado - Status', 'Escala - Código', 'Escala - Nome',
#        'Estabelecimento - Nome', 'Vínculo Empregatício - Código',
#        'Vínculo Empregatício - Nome', 'Chefia Imediata - Matrícula',
#        'Centro de Resultado - Código', 'Centro de Resultado - Nome'],
#       dtype='object')

# %%
base_ativos['Estabelecimento - Nome']=base_ativos['Estabelecimento - Nome'].apply(
    lambda x: x.strip()[-3:]
)

# %%
base_ativos
# Out:
#       Estabelecimento - Código  Matrícula             Nome - Primeiro Nome  \
# 0                           20         27  NILTON
# 1                           24         84  ALEXANDRE
# 2                           10         93  ELI
# 3                           10        111  ELIANE
# 4                           10        131  WALTER
# ...                        ...        ...                              ...
# 3056                        10      29860  LEONEL
# 3057                         3      29868  VICENTE
# 3058                        19      29866  REGINALDO
# 3059                        67      29869  GABRIELLA
# 3060                        19      29871  ORLANDO
#
#                                Nome - Sobrenome  Cargo - Código  \
# 0     DOS SANTOS                                            100
# 1     POLONI                                                498
# 2     SILVA                                                 164
# 3     RIBEIRO                                               336
# 4     FONTES                                                165
# ...                                         ...             ...
# 3056  FREEMAM JUNIOR                                       9335
# 3057  DA SILVA                                              585
# 3058  RIBEIRO JUNIOR                                        455
# 3059  DE MORAES                                            9335
# 3060  PEREIRA                                               499
#
#                               Cargo - Nome   Data de Nascimento  \
# 0     Enc Depósito                                  23/02/1966
# 1     Ger Geral I                                   30/04/1977
# 2     Vendedor(a) Televendas                        28/10/1967
# 3     Anl Contábil Pl                               23/08/1970
# 4     Vendedor(a)                                   13/06/1959
# ...                                    ...                  ...
# 3056  ASSESSOR DE LOJA                              18/04/1974
# 3057  Oficial Manutenção Eletricista                09/12/1968
# 3058  Ass Prevenção de Perdas                       17/10/1974
# 3059  ASSESSOR DE LOJA                              27/04/1999
# 3060  Ger Geral II                                  13/11/1971
#
#        Data da Admissão                     Situação do Empregado - Status  \
# 0           01/06/1991   ATIVO                                         ...
# 1           11/03/1993   ATIVO                                         ...
# 2           03/05/1993   ATIVO                                         ...
# 3           01/12/1993   ATIVO                                         ...
# 4           04/04/1994   Férias                                        ...
# ...                 ...                                                ...
# 3056        02/05/2022   ATIVO                                         ...
# 3057        02/05/2022   ATIVO                                         ...
# 3058        02/05/2022   ATIVO                                         ...
# 3059        02/05/2022   ATIVO                                         ...
# 3060        03/05/2022   ATIVO                                         ...
#
#       Escala - Código               Escala - Nome Estabelecimento - Nome  \
# 0                1230  0840/1700                                     ARI
# 1                1049  Escala Artigo 62 II da CL                     PAR
# 2                 200  8/18 SEG/QUI (SEX 8/17)                       MGN
# 3                 200  8/18 SEG/QUI (SEX 8/17)                       MGN
# 4                1249  0600/1420                                     MGN
# ...               ...                         ...                    ...
# 3056              106  8/1620 (SAB 10/1820)                          MGN
# 3057               10  750/1610(SEG/DOM)                             JDI
# 3058              118  14/2220(SEG/SAB)                              ZNO
# 3059               82  1340/22(SEG/DOM)                              AMO
# 3060                3  13:30 as 21:50 Segunda a                      ZNO
#
#       Vínculo Empregatício - Código           Vínculo Empregatício - Nome  \
# 0                                 1  Trabalhador CLT
# 1                                 1  Trabalhador CLT
# 2                                 7  Comissionados
# 3                                 1  Trabalhador CLT
# 4                                 7  Comissionados
# ...                             ...                                   ...
# 3056                              1  Trabalhador CLT
# 3057                              1  Trabalhador CLT
# 3058                              1  Trabalhador CLT
# 3059                              1  Trabalhador CLT
# 3060                              1  Trabalhador CLT
#
#      Chefia Imediata - Matrícula  Centro de Resultado - Código  \
# 0                          24816                        244406
# 1                          24757                        304401
# 2                          23904                        175403
# 3                          27580                        101104
# 4                          27460                        174403
# ...                          ...                           ...
# 3056                       11543                        174402
# 3057                       27511                        114402
# 3058                        9472                        254404
# 3059                       13255                        644403
# 3060                       16765                        254401
#
#                 Centro de Resultado - Nome
# 0     ARI - DEPOSITO LOJA
# 1     PAR - GERENCIA E SUPERVISAO
# 2     ENG - VENDAS
# 3     DAF - CONTABILIDADE GERAL
# 4     MGN - VENDAS
# ...                                    ...
# 3056  MGN - OPERACOES LOJA
# 3057  JDI - OPERACOES LOJA
# 3058  ZNO - PREVENCAO DE PERDAS
# 3059  AMO - VENDAS
# 3060  ZNO - GERENCIA E SUPERVISAO
#
# [3061 rows x 17 columns]

# %%
# Pegando da base de ativos somente parâmetros/colunas necessários 
ativos=base_ativos[[
    'Matrícula', 
    'Nome - Primeiro Nome',
    'Nome - Sobrenome', 
    'Cargo - Nome',
    'Data da Admissão',
    'Situação do Empregado - Status',
    'Estabelecimento - Nome',
    'Centro de Resultado - Código'
    ]].copy(deep=True)

# %%
ativos
# Out:
#       Matrícula             Nome - Primeiro Nome  \
# 0            27  NILTON
# 1            84  ALEXANDRE
# 2            93  ELI
# 3           111  ELIANE
# 4           131  WALTER
# ...         ...                              ...
# 3056      29860  LEONEL
# 3057      29868  VICENTE
# 3058      29866  REGINALDO
# 3059      29869  GABRIELLA
# 3060      29871  ORLANDO
#
#                                Nome - Sobrenome  \
# 0     DOS SANTOS
# 1     POLONI
# 2     SILVA
# 3     RIBEIRO
# 4     FONTES
# ...                                         ...
# 3056  FREEMAM JUNIOR
# 3057  DA SILVA
# 3058  RIBEIRO JUNIOR
# 3059  DE MORAES
# 3060  PEREIRA
#
#                               Cargo - Nome   Data da Admissão  \
# 0     Enc Depósito                                01/06/1991
# 1     Ger Geral I                                 11/03/1993
# 2     Vendedor(a) Televendas                      03/05/1993
# 3     Anl Contábil Pl                             01/12/1993
# 4     Vendedor(a)                                 04/04/1994
# ...                                    ...                ...
# 3056  ASSESSOR DE LOJA                            02/05/2022
# 3057  Oficial Manutenção Eletricista              02/05/2022
# 3058  Ass Prevenção de Perdas                     02/05/2022
# 3059  ASSESSOR DE LOJA                            02/05/2022
# 3060  Ger Geral II                                03/05/2022
#
#                          Situação do Empregado - Status  \
# 0     ATIVO                                         ...
# 1     ATIVO                                         ...
# 2     ATIVO                                         ...
# 3     ATIVO                                         ...
# 4     Férias                                        ...
# ...                                                 ...
# 3056  ATIVO                                         ...
# 3057  ATIVO                                         ...
# 3058  ATIVO                                         ...
# 3059  ATIVO                                         ...
# 3060  ATIVO                                         ...
#
#      Estabelecimento - Nome  Centro de Resultado - Código
# 0                       ARI                        244406
# 1                       PAR                        304401
# 2                       MGN                        175403
# 3                       MGN                        101104
# 4                       MGN                        174403
# ...                     ...                           ...
# 3056                    MGN                        174402
# 3057                    JDI                        114402
# 3058                    ZNO                        254404
# 3059                    AMO                        644403
# 3060                    ZNO                        254401
#
# [3061 rows x 8 columns]

# %%
# RENOMEANDO OS PARÂMETROS/COLUNAS DA BASE DE ativos DA esquerda para direita {'ESQUERDA':'DIREITA'}
RENOMEA={
    'Matrícula':'MATRICULA', 
    'Nome - Primeiro Nome':'NOME',
    'Nome - Sobrenome':'SOBRENOME', 
    'Cargo - Nome':'CARGO',
    'Data da Admissão':'DATA_ADMISSAO',
    'Situação do Empregado - Status':'STATUS',
    'Estabelecimento - Nome':'LOJA'
}

ativos.rename(columns=RENOMEA, inplace=True)

# %%
ativos['DATA_ADMISSAO']=pd.to_datetime(ativos['DATA_ADMISSAO'])

# %%
ativos['DATA_ADMISSAO']
# Out:
# 0      1991-01-06
# 1      1993-11-03
# 2      1993-03-05
# 3      1993-01-12
# 4      1994-04-04
#           ...
# 3056   2022-02-05
# 3057   2022-02-05
# 3058   2022-02-05
# 3059   2022-02-05
# 3060   2022-03-05
# Name: DATA_ADMISSAO, Length: 3061, dtype: datetime64[ns]

# %%
loja_nps_venda_alvo.columns
# Out:
# Index(['cod_loja', 'sigla_loja', 'Venda_Total', 'nps', 'id_mes',
#        'target_sales_store_1', 'target_sales_store_2', 'alvo',
#        'NPS_alcancado'],
#       dtype='object')

# %%
lojas_tina['sigla_loja'][lojas_tina['id_unn']==ID_UNN]
# Out:
# 0     IMI
# 1     ZNO
# 2     SOR
# 3     TAT
# 4     PGD
# 5     JDI
# 6     OSA
# 7     BEL
# 8     DPE
# 9     TAM
# 10    MGA
# 11    ARP
# 12    WHL
# 13    RDV
# 14    TBT
# 15    RPT
# 16    AMZ
# 17    ANH
# 18    MGN
# 19    SA1
# 20    TAB
# 21    PMG
# 22    ARI
# 23    SJC
# 24    PAR
# 25    MOR
# 26    GRU
# 27    PAM
# 28    CTG
# 29    PIR
# 30    UBE
# 31    BRG
# 32    TIR
# 33    CAT
# 34    PRU
# 35    CLI
# 36    SAN
# 37    RAP
# 38    SCA
# Name: sigla_loja, dtype: object

# %%
ativos.columns
# Out:
# Index(['MATRICULA', 'NOME', 'SOBRENOME', 'CARGO', 'DATA_ADMISSAO', 'STATUS',
#        'LOJA', 'Centro de Resultado - Código'],
#       dtype='object')

# %%
# CRIANDO BASE tina A PARTIR DA BASE DE ATIVOS MAIS RECENTE 
# 
tina=ativos[ativos['LOJA'].isin(lojas_tina['sigla_loja'][lojas_tina['id_unn']==ID_UNN])].copy(deep=True)

# %%
tina['LOJA'].unique()
# Out:
# array(['ARI', 'PAR', 'MGN', 'GRU', 'PGD', 'TAB', 'SA1', 'ANH', 'SAN',
#        'MOR', 'JDI', 'OSA', 'ZNO', 'ARP', 'PMG', 'BRG', 'RDV', 'RAP',
#        'TAM', 'SJC', 'TBT', 'SOR', 'IMI', 'BEL', 'CLI', 'WHL', 'TIR',
#        'MGA', 'PAM', 'PRU', 'CTG', 'CAT', 'PIR', 'DPE', 'UBE', 'TAT',
#        'RPT', 'AMZ', 'SCA'], dtype=object)

# %%
#  Função para calcular os dias ADMITIDOS dentro do período apurado
def admitidos_no_mes(data_admissao):
    global DATA_I, DATA_F
    if data_admissao <= DATA_I :
        dias_admitidos=DATA_F.day
    else:
        dias_admitidos=(DATA_F-data_admissao).days+1
    return dias_admitidos

# %%
(DATA_F-tina['DATA_ADMISSAO'].iloc[0]).days
# Out:
# 11437

# %%
# CALCULANDO QUANTOS DIAS O FUNCIONÁRIO ESTÁ ADMITIDO NO MÊS DA APURAÇÃO
tina['DIAS_ADMITIDOS']=tina['DATA_ADMISSAO'].apply(
    lambda x: admitidos_no_mes(x)
    ).copy()

# %%
# INCLUINDO INFORMAÇÃO SE O COLABORADOR ESTÁ ADMITIDO HÁ MAIS DE 15 DIAS DO PERÍODO DE APURAÇÃO
tina['MAIS_DE15DIAS_ADMITIDOS']=np.where(tina['DIAS_ADMITIDOS']>=MEIO_MES,"SIM", "NAO")

# %%
# LIMBANDO ESPAÇOS EM BRANCO DO STATUS
tina['STATUS']=tina['STATUS'].apply(
    lambda x: x.strip()
    )

# %%
tina['STATUS'].unique()
# Out:
# array(['ATIVO', 'Férias', 'SUSPENSÃO', 'Suspensão', 'Auxilio', 'Licença',
#        'Seguro', 'Atestado', 'Demissão'], dtype=object)

# %%
# Elimina espaços em branco dos CARGOs dos funcionários 
tina['CARGO']=tina['CARGO'].apply(
    lambda x: x.strip()
)
# CHECAGEM
tina['CARGO'].unique()
# Out:
# array(['Enc Depósito', 'Ger Geral I', 'Vendedor(a) Televendas',
#        'Anl Contábil Pl', 'Vendedor(a)', 'Coord de Mercado lll',
#        'Ger Operacional II', 'Ass Manut Serv Gerais', 'Ger Geral II',
#        'Assessor de Operações I', 'Anl Financeiro Jr', 'Ass Fiscal Sr',
#        'COMPRADOR ADM PL', 'Assessor de Operações II', 'Ass Financeiro',
#        'Ass Recebimento', 'Enc de Caixa', 'Ass Departamento Pessoal',
#        'Anl Financeiro Pl', 'Sup Operacional',
#        'COORD TECNOLOGIA DA INFORMACAO', 'DIR REGIONAL DE OPERACOES',
#        'Ger de Vendas I', 'ASSESSOR DE LOJA', 'Lider de Caixa',
#        'Repositor(a)', 'Oficial Manutenção Eletricista', 'Conferente',
#        'Ass Financeiro Sr', 'Enc Manutenção', 'Operador Empilhadeira',
#        'Anl Funcional SAP PL', 'Gerente de Preços', 'Aux Manutenção',
#        'Enc de Produto', 'Ass Recursos Humanos', 'Ger de Informática',
#        'Sup de Vendas', 'Ass Serviços ao Cliente', 'Ger Regional I',
#        'Ger Mercado II', 'Anl Infraestrut Pl', 'Anl Funcional SAP Sr',
#        'Anl Abastecimento Pl', 'Coord de Mercado II',
#        'Anl Mídias Sociais Jr', 'GERENTE COMERCIAL', 'GER REGIONAL',
#        'Ass de Expedição', 'Sup de Produto', 'Ass Recebimento Fiscal',
#        'Técnico Seguranca Trabalho Sr', 'Vendedor(a) Especialista',
#        'Anl Gestão Compras Pl', 'Enc SAC', 'Operador(a) Caixa',
#        'Ass Prevenção de Perdas', 'Anl Abastecimento Sr',
#        'Ger Operacional I', 'GERENTE DE RELACIONAMENTO E PRODUTO',
#        'Ger Geral III', 'Ger de Produto II', 'Coord de Serviços',
#        'Coord de EHS', 'Gerente Adm Financeiro', 'Médico do Trabalho',
#        'ANL RH REGIONAL PL', 'SUP DE RECURSOS HUMANOS',
#        'ENC DE OPERACOES', 'Anl Fiscal Pl',
#        'COORDENADOR PREVENCAO PERDAS', 'Anl Recebimento Fiscal Jr',
#        'Ger de Vendas II', 'Anl Recursos Humanos Jr', 'Enc CTN',
#        'Supervisor Financeiro', 'SUP CARTOES E SERV FINANCEIROS',
#        'Ger Recursos Humanos', 'Sup de Televendas', 'Ass Administrativo',
#        'Coord Fiscal', 'Anl Fiscal Jr', 'COORD CARTOES SERV FINANCEIROS',
#        'Ger Regional II', 'Enc Prevenção de Perda', 'Anl de Importação',
#        'Sup Administrativo', 'Ger de Infraestrutura',
#        'GER CANAIS DIGITAIS', 'Vendedor(a) Especialista Lider',
#        'Ger. Qualidade e EHS', 'COORD PREV E GESTAO DE FRAUDE',
#        'Dir de Marketing', 'Anl Recursos Humanos Pl', 'Anl Contábil Sr',
#        'Ger Desenvolv. Organizacional', 'Técnico de Edificações Sr',
#        'Enc Serviços ao Cliente', 'Coord Adm de Compras',
#        'Especialista de Preço', 'Ger de Prevencao de Perdas',
#        'Ger Compras Adm', 'Anl Serv Merchandising Pl', 'GER GERAL SR',
#        'COORD INTELIGENCIA MERCADO', 'Ger Plan e Gest de Categorias',
#        'Anl Prevenção Perdas Pl', 'Coord Controle Interno',
#        'ENC SEGURANCA PATRIMONIAL', 'GER REMUNERACAO E BENEFICIOS',
#        'SECRETARIA DIRETORIA', 'Sup Caixa', 'Anl Gestão Compras Jr',
#        'Ass Depósito', 'Dir Adm Financeiro', 'Ger Televendas',
#        'Oficial Manutenção', 'Ger de Vendas III',
#        'ASSIST RELACOES TRABALHISTAS', 'Coordenador de Merchandising',
#        'Atendente de Loja', 'Dir. Expansão e Novos Negócios',
#        'DIRETOR GERAL - DISTRIB BRASIL', 'Coord Comunicação Interna',
#        'Diretor de Informatica', 'Ger Novos Negocios', 'COORD EXPANSAO',
#        'Gerente Projetos Operações', 'Ger de Controladoria',
#        'Gerente de Omnicanalidade', 'Vendedor(a) Projetista',
#        'Anl Infraestrut Sr', 'Coord Financeiro(a)', 'Coord de Mercado I',
#        'COORD DE PROCESSOS', 'Anl Financeiro Sr', 'ASS ADM TELEVENDAS',
#        'Coord Recursos Humanos', 'COORDENADOR DE BI',
#        'Coordenador Compras', 'DESIGNER PROJETISTA', 'Comprador',
#        'Dir Recursos Humanos', 'ANALISTA DE BI SR', 'Ger de Produto I',
#        'Esp DHO', 'Ass Compras e Cadastro', 'Analista de Preços',
#        'COORD. MARKETING DE ATIVAÇÃO', 'Anl de Marketing Sr',
#        'DIRETOR COMERCIAL', 'SECRETARIA', 'Técnico de Edificações',
#        'Anl Relacionamento e Operações', 'Ass Fiscal Pl',
#        'Anl Recursos Humanos Sr', 'Analista de Preço Pl',
#        'Anl Infraestrut Jr', 'Anl de Logística Jr', 'Coord de Engenharia',
#        'GERENTE LOGISTICA', 'Gerente Operacional',
#        'ASSESSOR DE OPERACOES', 'COORDENADOR CONTABIL',
#        'GER PROD E SERV FINANCEIROS', 'Coord de Treinamento',
#        'Sup deProduto I', 'Ass Logistico Televenda', 'Supervisor Fiscal',
#        'GER DESENV DE SISTEMAS', 'Coord de Marketing',
#        'ESP DE SEGURANCA DE DADOS', 'Dir de Logística',
#        'ANL MARKETING DE ATIVACAO JR', 'Técnico Projetista',
#        'Anl Merchandising Sr', 'ESP DE CONTROLE E GESTAO',
#        'ASS INFRAESTRUTURA', 'COORD COMUNICACAO', 'Ger Marketing',
#        'Ass Compras', 'COORDENADOR DE PROJETOS', 'Coord  Abastecimento',
#        'ORCAMENTISTA', 'Ass Cadastro Jr', 'Estagiário(a)',
#        'Anl Merchandising Pl', 'Analista de Preço Jr',
#        'Anl Abastecimento Jr', 'Técnico Seguranca Trabalho Pl', 'Trainee',
#        'Dir Vendas e Operações', 'Coord Compras Administrativas',
#        'Anl Controle de Gestão Pl', 'GERENTE REGIONAL',
#        'Ger Contr de Gest Operacional', 'COMPRADOR ADM JR',
#        'Anl Arquitetura de Sistemas Sr', 'Ger Abast e Planej Logístico',
#        'Ass de Informática', 'VENDEDOR(A) TELEVENDAS', 'Vendedor Externo',
#        'Ger de Expansão', 'Menor Aprendiz', 'SUP RECEBIMENTO FISCAL',
#        'Anl Contábil Jr', 'Ass Serviço ao Cliente',
#        'Consultor de Vendas Externas', 'Anl PP Int Antifraude Sr',
#        'Coord Relac e Operações', 'Ass Contábil',
#        'Tec Manut Instal de Sistemas', 'ANALISTA ADMINISTRATIVO',
#        'Cientista de Dados Pl', 'Analista de Projetos Sr',
#        'Analista de Novos Negócios Jr', 'ASSISTENTE DE ABASTECIMENTO',
#        'Ass Financeiro Jr', 'Anl Merchandising Jr',
#        'Anl Comunicação Interna Jr', 'Anl Serv Financeiro Sr'],
#       dtype=object)

# %%
# INCLUINDO ELEGIBILIDADE DA LOJA
tina['LOJA_ELEGIVEL']=np.where(tina['LOJA'].isin(lojas_elegiveis['sigla_loja']),'SIM','NAO')

# %%
tina
# Out:
#       MATRICULA                             NOME  \
# 0            27  NILTON
# 1            84  ALEXANDRE
# 2            93  ELI
# 3           111  ELIANE
# 4           131  WALTER
# ...         ...                              ...
# 3054      29863  DREYFUS
# 3056      29860  LEONEL
# 3057      29868  VICENTE
# 3058      29866  REGINALDO
# 3060      29871  ORLANDO
#
#                                       SOBRENOME  \
# 0     DOS SANTOS
# 1     POLONI
# 2     SILVA
# 3     RIBEIRO
# 4     FONTES
# ...                                         ...
# 3054  DE ANDRADE
# 3056  FREEMAM JUNIOR
# 3057  DA SILVA
# 3058  RIBEIRO JUNIOR
# 3060  PEREIRA
#
#                                CARGO DATA_ADMISSAO  STATUS LOJA  \
# 0                       Enc Depósito    1991-01-06   ATIVO  ARI
# 1                        Ger Geral I    1993-11-03   ATIVO  PAR
# 2             Vendedor(a) Televendas    1993-03-05   ATIVO  MGN
# 3                    Anl Contábil Pl    1993-01-12   ATIVO  MGN
# 4                        Vendedor(a)    1994-04-04  Férias  MGN
# ...                              ...           ...     ...  ...
# 3054                 Sup Operacional    2022-02-05   ATIVO  BEL
# 3056                ASSESSOR DE LOJA    2022-02-05   ATIVO  MGN
# 3057  Oficial Manutenção Eletricista    2022-02-05   ATIVO  JDI
# 3058         Ass Prevenção de Perdas    2022-02-05   ATIVO  ZNO
# 3060                    Ger Geral II    2022-03-05   ATIVO  ZNO
#
#       Centro de Resultado - Código  DIAS_ADMITIDOS MAIS_DE15DIAS_ADMITIDOS  \
# 0                           244406              30                     SIM
# 1                           304401              30                     SIM
# 2                           175403              30                     SIM
# 3                           101104              30                     SIM
# 4                           174403              30                     SIM
# ...                            ...             ...                     ...
# 3054                        314401              30                     SIM
# 3056                        174402              30                     SIM
# 3057                        114402              30                     SIM
# 3058                        254404              30                     SIM
# 3060                        254401              30                     SIM
#
#      LOJA_ELEGIVEL
# 0              NAO
# 1              NAO
# 2              NAO
# 3              NAO
# 4              NAO
# ...            ...
# 3054           NAO
# 3056           NAO
# 3057           SIM
# 3058           NAO
# 3060           NAO
#
# [2324 rows x 11 columns]

# %% [markdown]
# JUNTANDO BASE DE AFASTADOS E DE RETORNOS DO MÊS DE APURAÇÃO

# %%
# BASE DE DATA DE RETORNO DOS COLABORADORES 
# 
# Lendo base de retorno
print("Lendo base de retorno no arquivo:")
print(F_RETORNO)
base_retorno = pd.read_excel(F_RETORNO) # afastados=
# Out:
# Lendo base de retorno no arquivo:
# C:/apuracao/TELHANORTE/2022/mai/ORIGINAIS/Empregados-Afastados-20220401-a-20220430.xlsx

# %%
# BASE DE AFASTADOS 
# 
# Lendo base de afastados
print("Lendo base de afastados no arquivo:")
print(F_AFASTADOS)
base_afastados = pd.read_excel(F_AFASTADOS) # afastados=
# Out:
# Lendo base de afastados no arquivo:
# C:/apuracao/TELHANORTE/2022/mai/ORIGINAIS/Empregados-Afastados-19000101-a-20220430.xlsx

# %%
base_afastados.columns
# Out:
# Index(['Empresa', 'Código do Estabelecimento', 'Descrição do Estabelecimento',
#        'Matrícula', 'Nome', 'Função', 'Centro de Resultado',
#        'Descrição de Centro de Resultado', 'Número de Dias',
#        'Data de Admissão', 'Data de Afastamento', 'Data de Retorno',
#        'Tipo de Afastamento', 'Motivo Interno do Afastamento',
#        'Data Previsão Perícia INSS', 'Protocolo Agendamento Perícia',
#        'Número Benefício'],
#       dtype='object')

# %%
base_retorno.columns
# Out:
# Index(['Empresa', 'Código do Estabelecimento', 'Descrição do Estabelecimento',
#        'Matrícula', 'Nome', 'Função', 'Centro de Resultado',
#        'Descrição de Centro de Resultado', 'Número de Dias',
#        'Data de Admissão', 'Data de Afastamento', 'Data de Retorno',
#        'Tipo de Afastamento', 'Motivo Interno do Afastamento',
#        'Data Previsão Perícia INSS', 'Protocolo Agendamento Perícia',
#        'Número Benefício'],
#       dtype='object')

# %%
base_retorno
# Out:
#      Empresa  Código do Estabelecimento  \
# 0          1                         57
# 1          1                         10
# 2          1                         20
# 3          1                         22
# 4          1                         63
# ..       ...                        ...
# 641        4                         10
# 642        4                         44
# 643        4                         15
# 644        4                         59
# 645        4                          1
#
#                     Descrição do Estabelecimento  Matrícula  \
# 0    Saint-Gobain Distribuição Brasil Ltda - SAN      27539
# 1    Saint-Gobain Distribuição Brasil Ltda - MGN      14023
# 2    Saint-Gobain Distribuição Brasil Ltda - ARI      12858
# 3    Saint-Gobain Distribuição Brasil Ltda - OSA       4901
# 4    Saint-Gobain Distribuicao Brasil Ltda - SCA      23674
# ..                                           ...        ...
# 641   TUMELERO MATERIAIS DE CONSTRUCAO LTDA - CD       7491
# 642  TUMELERO MATERIAIS DE CONSTRUCAO LTDA - SMA      23902
# 643  TUMELERO MATERIAIS DE CONSTRUCAO LTDA - RGD      12277
# 644  TUMELERO MATERIAIS DE CONSTRUCAO LTDA - MED      11820
# 645  TUMELERO MATERIAIS DE CONSTRUCAO LTDA - MTZ       1187
#
#                                  Nome                       Função  \
# 0      ABDIAS DA SILVA PEREIRA JUNIOR             ASSESSOR DE LOJA
# 1           ADALGIZA CRISTINA DE LIMA               Lider de Caixa
# 2                     ADAMS DE MORAES             ASSESSOR DE LOJA
# 3        ADEMILSON MODOLO DE OLIVEIRA                  Ger Geral I
# 4             ADMILSON CARDOSO JUNIOR              Sup Operacional
# ..                                ...                          ...
# 641                     VINICIUS MAIA  OPERADOR DE EMPILHADEIRA II
# 642  VITOR DA ROSA PENADEZ DOS SANTOS              VENDEDOR JUNIOR
# 643      WENDREO PIERRE SALAZAR SILVA              VENDEDOR JUNIOR
# 644          WILLIAM TEIXEIRA BARBOSA              VENDEDOR JUNIOR
# 645       ZENAURO DOS SANTOS SILVEIRA    ANALISTA DE SUPORTE PLENO
#
#      Centro de Resultado    Descrição de Centro de Resultado  Número de Dias  \
# 0                 574402                SAN - Operações Loja              87
# 1                 174402                MGN - OPERACOES LOJA               3
# 2                 244402                ARI - OPERACOES LOJA              30
# 3                 274401         OSA - GERENCIA E SUPERVISAO              20
# 4                 614401         SCA - Gerencia e Supervisão              20
# ..                   ...                                 ...             ...
# 641               546072  CD1 - TAPECARIA MOVEIS E ABERTURAS               3
# 642               248402                        SMA - VENDAS               5
# 643               908402                        RGD - VENDAS              30
# 644               338402                        MED - VENDAS              30
# 645               100540            Tecnologia da Informação              20
#
#     Data de Admissão Data de Afastamento Data de Retorno  \
# 0         11/11/2019          09/12/2021      06/03/2022
# 1         01/12/2009          18/03/2022      21/03/2022
# 2         15/01/2009          01/03/2022      31/03/2022
# 3         03/09/2001          08/03/2022      28/03/2022
# 4         11/11/2015          10/02/2022      02/03/2022
# ..               ...                 ...             ...
# 641       01/09/2010          03/03/2022      06/03/2022
# 642       01/02/2022          24/03/2022      29/03/2022
# 643       02/09/2019          01/03/2022      31/03/2022
# 644       01/02/2018          02/02/2022      04/03/2022
# 645       01/12/1989          14/02/2022      06/03/2022
#
#       Tipo de Afastamento  Motivo Interno do Afastamento  \
# 0     BE - Auxilio Doença                            NaN
# 1    AT - Atestado Médico                            NaN
# 2             FE - Férias                            NaN
# 3             FE - Férias                            NaN
# 4             FE - Férias                            NaN
# ..                    ...                            ...
# 641  AT - Atestado Médico                            NaN
# 642  AT - Atestado Médico                            NaN
# 643           FE - Férias                            NaN
# 644           FE - Férias                            NaN
# 645           FE - Férias                            NaN
#
#      Data Previsão Perícia INSS  Protocolo Agendamento Perícia  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# ..                          ...                            ...
# 641                         NaN                            NaN
# 642                         NaN                            NaN
# 643                         NaN                            NaN
# 644                         NaN                            NaN
# 645                         NaN                            NaN
#
#      Número Benefício
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 641               NaN
# 642               NaN
# 643               NaN
# 644               NaN
# 645               NaN
#
# [646 rows x 17 columns]

# %%
# PARÂMETROS NECESSÁRIOS DOS AFASTADOS
PARAMETROS=[
    'Empresa', 
    'Descrição do Estabelecimento', 
    'Matrícula', 
    'Nome',
    'Função', 
    'Centro de Resultado',
    'Número de Dias', 
    'Data de Admissão', 
    'Data de Afastamento', 
    'Data de Retorno',
    'Tipo de Afastamento'
]

# %%
# JUNTANDO BASE DE AFASTADOS COM O DE RETORNO
#     Somente dos parâmetros necessários
afastados = pd.concat(
    [base_afastados[PARAMETROS].copy(deep=True), 
    base_retorno[PARAMETROS].copy(deep=True)], 
    ignore_index=True
    )

# %%
afastados['Data de Admissão']=pd.to_datetime(afastados['Data de Admissão'], format="%d/%m/%Y")
afastados['Data de Afastamento']=pd.to_datetime(afastados['Data de Afastamento'], format="%d/%m/%Y")
afastados['Data de Retorno']=pd.to_datetime(afastados['Data de Retorno'], format="%d/%m/%Y")

# %%
# Para renomear  os parâmetros da base de afastados
RENOMEA={
    'Empresa': 'EMPRESA',
    'Descrição do Estabelecimento': 'LOJA', 
    'Matrícula':'MATRICULA', 
    'Nome':'NOME',
    'Data de Admissão':'DATA_ADMISSAO', 
    'Data de Afastamento':'DATA_AFASTAMENTO', 
    'Data de Retorno':'DATA_RETORNO',   
    'Tipo de Afastamento':'MOTIVO'
    }

# Renomeando as colunas da base de afastados com nome da direita pelo da esquerda
afastados.rename(columns=RENOMEA, inplace=True)

# %%
# EXTRAINDO SIGLA DA LOJA
afastados['LOJA']=afastados['LOJA'].apply(
    lambda x: x.strip()[-3:]
)
afastados
# Out:
#       EMPRESA LOJA  MATRICULA                              NOME  \
# 0           1  SAN      27539    ABDIAS DA SILVA PEREIRA JUNIOR
# 1           1  CLI      28545         ADELSON DOS SANTOS JUNIOR
# 2           1  JDI       7792            ADONEL OSORIO DE SOUSA
# 3           1  IMI      28524           ADRIANA PEREIRA MILITAO
# 4           1  RAP      23792                     ADRIANA PUPIN
# ...       ...  ...        ...                               ...
# 1154        4   CD       7491                     VINICIUS MAIA
# 1155        4  SMA      23902  VITOR DA ROSA PENADEZ DOS SANTOS
# 1156        4  RGD      12277      WENDREO PIERRE SALAZAR SILVA
# 1157        4  MED      11820          WILLIAM TEIXEIRA BARBOSA
# 1158        4  MTZ       1187       ZENAURO DOS SANTOS SILVEIRA
#
#                            Função  Centro de Resultado  Número de Dias  \
# 0                ASSESSOR DE LOJA               574402              38
# 1         Assessor de Operações I               524406              30
# 2                    Repositor(a)               114406            2429
# 3                ASSESSOR DE LOJA               204402              10
# 4                     Vendedor(a)               554403              30
# ...                           ...                  ...             ...
# 1154  OPERADOR DE EMPILHADEIRA II               546072               3
# 1155              VENDEDOR JUNIOR               248402               5
# 1156              VENDEDOR JUNIOR               908402              30
# 1157              VENDEDOR JUNIOR               338402              30
# 1158    ANALISTA DE SUPORTE PLENO               100540              20
#
#      DATA_ADMISSAO DATA_AFASTAMENTO DATA_RETORNO  \
# 0       2019-11-11       2022-03-06   2022-04-13
# 1       2020-12-07       2022-03-17   2022-04-16
# 2       2004-11-12       2015-08-06          NaT
# 3       2020-12-01       2022-03-29   2022-04-08
# 4       2016-02-11       2022-03-18   2022-04-17
# ...            ...              ...          ...
# 1154    2010-09-01       2022-03-03   2022-03-06
# 1155    2022-02-01       2022-03-24   2022-03-29
# 1156    2019-09-02       2022-03-01   2022-03-31
# 1157    2018-02-01       2022-02-02   2022-03-04
# 1158    1989-12-01       2022-02-14   2022-03-06
#
#                                    MOTIVO
# 0     SC - Suspensão Contrato de Trabalho
# 1                             FE - Férias
# 2     SC - Suspensão Contrato de Trabalho
# 3                    AT - Atestado Médico
# 4                             FE - Férias
# ...                                   ...
# 1154                 AT - Atestado Médico
# 1155                 AT - Atestado Médico
# 1156                          FE - Férias
# 1157                          FE - Férias
# 1158                          FE - Férias
#
# [1159 rows x 11 columns]

# %%
# AFASTADOS SOMENTE EMPRESA SELECIONADA ACIMA ID_UNN
afastados=afastados[afastados['EMPRESA']==ID_UNN]

# %%
# SOMENTE LOJAS TINA DA TELHANORTE
lojas_tina_telha=lojas_tina[['cod_loja', 'sigla_loja']][lojas_tina['id_unn']==1]

# %%
# AFASTADOS SOMENTE TINA
afastados=afastados[afastados['LOJA'].isin(lojas_tina_telha['sigla_loja'])].copy(deep=True)
afastados
# Out:
#       EMPRESA LOJA  MATRICULA                            NOME  \
# 0           1  SAN      27539  ABDIAS DA SILVA PEREIRA JUNIOR
# 1           1  CLI      28545       ADELSON DOS SANTOS JUNIOR
# 2           1  JDI       7792          ADONEL OSORIO DE SOUSA
# 3           1  IMI      28524         ADRIANA PEREIRA MILITAO
# 4           1  RAP      23792                   ADRIANA PUPIN
# ...       ...  ...        ...                             ...
# 997         1  MGN      27626  WILLIANNY DAYSE JESUS OLIVEIRA
# 998         1  CLI      18114      WILSON LUIZ SOUZA TEIXEIRA
# 999         1  MGN      27855        YASMIM DE BRITO FERREIRA
# 1000        1  MGN      27855        YASMIM DE BRITO FERREIRA
# 1001        1  TIR      28623           ZEMARIO SANTOS BONFIM
#
#                         Função  Centro de Resultado  Número de Dias  \
# 0             ASSESSOR DE LOJA               574402              38
# 1      Assessor de Operações I               524406              30
# 2                 Repositor(a)               114406            2429
# 3             ASSESSOR DE LOJA               204402              10
# 4                  Vendedor(a)               554403              30
# ...                        ...                  ...             ...
# 997           ASSESSOR DE LOJA               174402               3
# 998               Enc Depósito               524406              30
# 999    Ass Serviços ao Cliente               808568               7
# 1000   Ass Serviços ao Cliente               808568               7
# 1001  Assessor de Operações II               354406              30
#
#      DATA_ADMISSAO DATA_AFASTAMENTO DATA_RETORNO  \
# 0       2019-11-11       2022-03-06   2022-04-13
# 1       2020-12-07       2022-03-17   2022-04-16
# 2       2004-11-12       2015-08-06          NaT
# 3       2020-12-01       2022-03-29   2022-04-08
# 4       2016-02-11       2022-03-18   2022-04-17
# ...            ...              ...          ...
# 997     2019-12-02       2022-03-10   2022-03-13
# 998     2012-02-01       2022-02-17   2022-03-19
# 999     2020-02-17       2022-03-22   2022-03-29
# 1000    2020-02-17       2022-02-26   2022-03-05
# 1001    2021-01-05       2022-01-31   2022-03-02
#
#                                    MOTIVO
# 0     SC - Suspensão Contrato de Trabalho
# 1                             FE - Férias
# 2     SC - Suspensão Contrato de Trabalho
# 3                    AT - Atestado Médico
# 4                             FE - Férias
# ...                                   ...
# 997                  AT - Atestado Médico
# 998                           FE - Férias
# 999                  AT - Atestado Médico
# 1000                 AT - Atestado Médico
# 1001                          FE - Férias
#
# [698 rows x 11 columns]

# %%
afastados[afastados['MATRICULA']==6068]
# Out:
#      EMPRESA LOJA  MATRICULA                      NOME        Função  \
# 228        1  PMG       6068  LINDOVAL MATIAS DA SILVA  Repositor(a)
#
#      Centro de Resultado  Número de Dias DATA_ADMISSAO DATA_AFASTAMENTO  \
# 228               234402             968    2003-02-05       2019-08-06
#
#     DATA_RETORNO                               MOTIVO
# 228          NaT  SC - Suspensão Contrato de Trabalho

# %%
#  Função para calcular os dias de afastamento dentro do período apurado
def afastamento_do_mes(data_afastamento, data_retorno):
    global DATA_I, DATA_F
    if data_afastamento >= DATA_I and data_retorno <= DATA_F:
        dias_afastados=(data_retorno-data_afastamento).days
    elif (data_afastamento < DATA_I or pd.isnull(data_afastamento))  and data_retorno <= DATA_F:
        dias_afastados=(data_retorno-DATA_I).days
    elif data_afastamento >= DATA_I and (data_retorno > DATA_F or pd.isnull(data_retorno)):
        dias_afastados=(DATA_F-data_afastamento).days+1
    elif (data_afastamento < DATA_I or pd.isnull(data_afastamento)) and (data_retorno > DATA_F or pd.isnull(data_retorno)):
        dias_afastados=(DATA_F.day)
    elif (data_afastamento < DATA_I or pd.isnull(data_afastamento)) and (data_retorno < DATA_I):
        dias_afastados=(DATA_F.day-DATA_F.day)
    else:
        print("ERRO")
        dias_afastados=0

    return dias_afastados

# %%
# Contando os dias de afastamento para cada período de afastamento considerando o período de apuração
afastados['dias_afastados']=afastados.apply(
    lambda x: afastamento_do_mes(x['DATA_AFASTAMENTO'],x['DATA_RETORNO']), axis=1)

# %%
afastados
# Out:
#       EMPRESA LOJA  MATRICULA                            NOME  \
# 0           1  SAN      27539  ABDIAS DA SILVA PEREIRA JUNIOR
# 1           1  CLI      28545       ADELSON DOS SANTOS JUNIOR
# 2           1  JDI       7792          ADONEL OSORIO DE SOUSA
# 3           1  IMI      28524         ADRIANA PEREIRA MILITAO
# 4           1  RAP      23792                   ADRIANA PUPIN
# ...       ...  ...        ...                             ...
# 997         1  MGN      27626  WILLIANNY DAYSE JESUS OLIVEIRA
# 998         1  CLI      18114      WILSON LUIZ SOUZA TEIXEIRA
# 999         1  MGN      27855        YASMIM DE BRITO FERREIRA
# 1000        1  MGN      27855        YASMIM DE BRITO FERREIRA
# 1001        1  TIR      28623           ZEMARIO SANTOS BONFIM
#
#                         Função  Centro de Resultado  Número de Dias  \
# 0             ASSESSOR DE LOJA               574402              38
# 1      Assessor de Operações I               524406              30
# 2                 Repositor(a)               114406            2429
# 3             ASSESSOR DE LOJA               204402              10
# 4                  Vendedor(a)               554403              30
# ...                        ...                  ...             ...
# 997           ASSESSOR DE LOJA               174402               3
# 998               Enc Depósito               524406              30
# 999    Ass Serviços ao Cliente               808568               7
# 1000   Ass Serviços ao Cliente               808568               7
# 1001  Assessor de Operações II               354406              30
#
#      DATA_ADMISSAO DATA_AFASTAMENTO DATA_RETORNO  \
# 0       2019-11-11       2022-03-06   2022-04-13
# 1       2020-12-07       2022-03-17   2022-04-16
# 2       2004-11-12       2015-08-06          NaT
# 3       2020-12-01       2022-03-29   2022-04-08
# 4       2016-02-11       2022-03-18   2022-04-17
# ...            ...              ...          ...
# 997     2019-12-02       2022-03-10   2022-03-13
# 998     2012-02-01       2022-02-17   2022-03-19
# 999     2020-02-17       2022-03-22   2022-03-29
# 1000    2020-02-17       2022-02-26   2022-03-05
# 1001    2021-01-05       2022-01-31   2022-03-02
#
#                                    MOTIVO  dias_afastados
# 0     SC - Suspensão Contrato de Trabalho              12
# 1                             FE - Férias              15
# 2     SC - Suspensão Contrato de Trabalho              30
# 3                    AT - Atestado Médico               7
# 4                             FE - Férias              16
# ...                                   ...             ...
# 997                  AT - Atestado Médico             -19
# 998                           FE - Férias             -13
# 999                  AT - Atestado Médico              -3
# 1000                 AT - Atestado Médico             -27
# 1001                          FE - Férias             -30
#
# [698 rows x 12 columns]

# %%
# CHECAGEM
# Verificando se há matrículas com mais de um afastamento no período apurado
afastados[afastados['MATRICULA']==6068]
# Out:
#      EMPRESA LOJA  MATRICULA                      NOME        Função  \
# 228        1  PMG       6068  LINDOVAL MATIAS DA SILVA  Repositor(a)
#
#      Centro de Resultado  Número de Dias DATA_ADMISSAO DATA_AFASTAMENTO  \
# 228               234402             968    2003-02-05       2019-08-06
#
#     DATA_RETORNO                               MOTIVO  dias_afastados
# 228          NaT  SC - Suspensão Contrato de Trabalho              30

# %%
# CHECAGEM
#  Para verificar o afastamento de uma matrícula específica
afastados[afastados['MATRICULA']==28143]
# Out:
#      EMPRESA LOJA  MATRICULA                    NOME            Função  \
# 68         1  MGN      28143  DAIANE DE SOUZA MIGUEL  ASSESSOR DE LOJA
# 595        1  MGN      28143  DAIANE DE SOUZA MIGUEL  ASSESSOR DE LOJA
# 596        1  MGN      28143  DAIANE DE SOUZA MIGUEL  ASSESSOR DE LOJA
#
#      Centro de Resultado  Número de Dias DATA_ADMISSAO DATA_AFASTAMENTO  \
# 68                174402              15    2020-09-01       2022-03-29
# 595               174402               7    2020-09-01       2022-03-21
# 596               174402               7    2020-09-01       2022-03-14
#
#     DATA_RETORNO                MOTIVO  dias_afastados
# 68    2022-04-13  AT - Atestado Médico              12
# 595   2022-03-28  AT - Atestado Médico              -4
# 596   2022-03-21  AT - Atestado Médico             -11

# %%
# SOMANDO OS DIAS AFASTADOS POR MATRÍCULA
dias_afastados_por_matricula=afastados.groupby(
    ['EMPRESA', 'LOJA','MATRICULA', 'NOME']
    )['dias_afastados'].sum().reset_index(name='dias_afastados_totais')

# %%
dias_afastados_por_matricula[dias_afastados_por_matricula['MATRICULA']==6068]
# Out:
#      EMPRESA LOJA  MATRICULA                      NOME  dias_afastados_totais
# 399        1  PMG       6068  LINDOVAL MATIAS DA SILVA                     30

# %%
# dias_afastados_por_matricula_telha=pd.merge(
#     dias_afastados_por_matricula[['LOJA', 'MATRICULA', 'dias_afastados_totais']
#         ][(dias_afastados_por_matricula['EMPRESA']==ID_UNN) &
#         (dias_afastados_por_matricula['LOJA'].isin(lojas_tina['cod_loja']))
#         ],
#     lojas_tina[['cod_loja', 'sigla_loja']][lojas_tina['id_unn']==ID_UNN].rename(columns={
#         'cod_loja':'COD_LOJA',
#         'sigla_loja':'LOJA'}),
#     how='left',
#     on='COD_LOJA'
#)

# %%
# pd.merge(
#     dias_afastados_por_matricula[['COD_LOJA', 'MATRICULA', 'dias_afastados_totais']
#         ][(dias_afastados_por_matricula['EMPRESA']==ID_UNN) &
#         (dias_afastados_por_matricula['COD_LOJA'].isin(lojas_tina['cod_loja']))
#         ],
#     lojas_tina[['cod_loja', 'sigla_loja']][lojas_tina['id_unn']==ID_UNN].rename(columns={
#         'cod_loja':'COD_LOJA',
#         'sigla_loja':'LOJA'}),
#     how='left',
#     on='COD_LOJA'
# )

# %%
tina[tina['MATRICULA']==6068]
# Out:
#      MATRICULA                             NOME  \
# 101       6068  LINDOVAL
#
#                                      SOBRENOME         CARGO DATA_ADMISSAO  \
# 101  DA SILVA                                   Repositor(a)    2003-05-02
#
#         STATUS LOJA  Centro de Resultado - Código  DIAS_ADMITIDOS  \
# 101  Suspensão  PMG                        234402              30
#
#     MAIS_DE15DIAS_ADMITIDOS LOJA_ELEGIVEL
# 101                     SIM           NAO

# %%
# INCLUINDO DIAS AFASTADOS TOTAIS DA MATRÍCULA
tina_afastados=pd.merge(
    tina,
    dias_afastados_por_matricula[
        ['MATRICULA','dias_afastados_totais']
        ],
        how='left',
        on=['MATRICULA']
        )

# %%
# PREENCHENDO COM ZERO ATIVOS SEM AFASTAMENTOS
tina_afastados['dias_afastados_totais'].fillna(0, inplace=True)

# %%
tina_afastados[tina_afastados['MATRICULA']==25333]
# Out:
#      MATRICULA                             NOME  \
# 964      25333  ALDERICO
#
#                                      SOBRENOME         CARGO DATA_ADMISSAO  \
# 964  QUEIROZ                                    Repositor(a)    2017-09-11
#
#       STATUS LOJA  Centro de Resultado - Código  DIAS_ADMITIDOS  \
# 964  Auxilio  PMG                        234406              30
#
#     MAIS_DE15DIAS_ADMITIDOS LOJA_ELEGIVEL  dias_afastados_totais
# 964                     SIM           NAO                   30.0

# %%
# CALCULANDO DIAS ATIVOS NO PERÍODO DE APURAÇÃO CONSIDERANDO A DATA DE ADMISSÃO
tina_afastados['DIAS_ATIVOS']=tina_afastados['DIAS_ADMITIDOS']-tina_afastados['dias_afastados_totais']

# %%
tina_afastados[tina_afastados['MATRICULA']==6068]
# Out:
#     MATRICULA                             NOME  \
# 90       6068  LINDOVAL
#
#                                     SOBRENOME         CARGO DATA_ADMISSAO  \
# 90  DA SILVA                                   Repositor(a)    2003-05-02
#
#        STATUS LOJA  Centro de Resultado - Código  DIAS_ADMITIDOS  \
# 90  Suspensão  PMG                        234402              30
#
#    MAIS_DE15DIAS_ADMITIDOS LOJA_ELEGIVEL  dias_afastados_totais  DIAS_ATIVOS
# 90                     SIM           NAO                   30.0          0.0

# %%
tina_afastados['MAIS_DE15DIAS_ATIVOS']=np.where(
    tina_afastados['DIAS_ATIVOS']>=MEIO_MES, 'SIM','NAO'
    )

# %%
tina_afastados.columns
# Out:
# Index(['MATRICULA', 'NOME', 'SOBRENOME', 'CARGO', 'DATA_ADMISSAO', 'STATUS',
#        'LOJA', 'Centro de Resultado - Código', 'DIAS_ADMITIDOS',
#        'MAIS_DE15DIAS_ADMITIDOS', 'LOJA_ELEGIVEL', 'dias_afastados_totais',
#        'DIAS_ATIVOS', 'MAIS_DE15DIAS_ATIVOS'],
#       dtype='object')

# %%
# PARA RENOMEAR PARÂMETROS DE ALVO E NPS E INCLUIR NA PLANILHA DE CHECAGEM
RENOMEA={
    'sigla_loja':'LOJA',
    'alvo':'ALVO_ALCANCADO',
    'nps':'NPS'
    }

# %%
# PREPARANDO PLANILHA DE CHECAGEM
tina_tudo=pd.merge(
    tina_afastados,
    loja_nps_venda_alvo[['sigla_loja', 'alvo','nps']].rename(columns=RENOMEA),
    how='left',
    on='LOJA'
    )

# %%
tina_copia=tina_tudo

# %%
# CARREGANDO TODOS OS CARGOS CONTEMPLADOS PELA PREMIAÇÃO COLETIVA
cargos=pd.read_csv(F_CARGOS, sep=';')

# %%
# ATRIBUINDO O GRUPO DE PREMIAÇÃO PARA CADA CARGO
tina_tudo=pd.merge(
    tina_tudo, 
    cargos.rename(columns={'Cargo':'CARGO'}),
    how='left',
    on='CARGO'
    )

# %%
tina_tudo['Grupo'].fillna('NAO TINA', inplace=True)

# %%
# Função para atribuir valor da premiação dependendo do grupo de cargo
def premiacao_alvo(grupo,alvo):
    global PREMIOS
    alvo1 = dict(zip(PREMIOS['Grupo'], PREMIOS['ALVO1']))
    alvo2 = dict(zip(PREMIOS['Grupo'], PREMIOS['ALVO2']))
    if alvo == 'ALVO1':
        valor=alvo1[grupo]
    elif alvo == 'ALVO2':
        valor=alvo2[grupo]
    elif alvo == 'NAO':
        valor = 0.0
    else: valor=0.0
    return valor

# %%
# Atribuindo valor da premiação dependendo do grupo de cargo
tina_tudo['PREMIACAO']=tina_tudo.apply(
    lambda x: premiacao_alvo(
        x['Grupo'],x['ALVO_ALCANCADO'],
    ), axis=1)

# %%
tina_tudo['FALTAS']=np.where(tina_tudo['MATRICULA'].isin(faltas['MATRICULA']),'SIM','NAO')

# %%
#Salvando verba
# Entradas: v verba, n nome_verba, x numero_verba, f f_nome
def salva_verba(verba,num_verba,arq_nome):
#    v.rename(columns={ v.columns[0]: 'MATRICULA'}, inplace=True)
    verba.rename(columns={ verba.columns[1]: "VALOR" }, inplace=True)
    verba['ZERO'] = 0
    verba['VERBA'] = num_verba
    verba=verba[['MATRICULA', 'ZERO', 'VERBA','VALOR']]
    verba = verba[verba['VALOR'] > 0]
    # Saving as a excel file for RH
    writer = pd.ExcelWriter(arq_nome, engine='xlsxwriter')  # #
    verba.to_excel(writer, sheet_name="VERBA "+str(num_verba), index=False)
    writer.save()

# %%
# Salva verba apuração coletiva
salva_verba(
    tina_tudo[['MATRICULA', 'PREMIACAO']][
        (tina_tudo['LOJA_ELEGIVEL']=='SIM') &
        (tina_tudo['MAIS_DE15DIAS_ATIVOS']=='SIM') &
        (tina_tudo['FALTAS']=='NAO')
    ].copy(),4117,FILE_SAI)

# %%
# Salva verba apuração coletiva
salva_verba(
    tina_tudo[['MATRICULA', 'PREMIACAO']][
        (tina_tudo['LOJA_ELEGIVEL']=='SIM') &
        (tina_tudo['MAIS_DE15DIAS_ATIVOS']=='SIM')
    ].copy(),4117,FILE_SAI_SEM)

# %%
# SALVA PLANILHA DE CHECAGEM
tina_tudo.to_excel(FILE_CHECAGEM, index=False)
